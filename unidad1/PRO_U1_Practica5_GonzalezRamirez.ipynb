# %% [markdown]
# #Probabilidad y Estadística
# ### Facilitador: José Gabriel Rodríguez Rivas
# ### Alumno: Ángel Michel González Ramírez

# %%
from statistics import*

# %%
#Lista de calificaciones de probabilidad del grupo a:
grupoa=[70,70,65,90,100,95,45,80,73,55,100,93]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 55, 100, 93]

# %%
#La función type nos devuelve el tipo de dato de la variable:
type(grupoa)
# Out:
# list

# %%
#Sacar la media con una formula:
prom=sum(grupoa)/len(grupoa)
print(prom)
# Out:
# 78.0

# %%
#Utilizar la función mean que esta en la librería statistics para sacar el promedio:
prom2=mean(grupoa)
print(prom2)
# Out:
# 78

# %%
#Determinar el valor de la mediana
mediana=median(grupoa)
print(mediana)
# Out:
# 76.5

# %% [markdown]
# ##Ejemplo 2:

# %%
tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#Podemos poner al lado el metodo mean, o hacer uso de una variable como en el bloque siguiente.
print("El tiempo promedio de los corredores es:", mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es: 17.322

# %%
#Aquí hicimos uso de una variable.
mediana=median(tiempos100mts)
print("La mediana de los tiempos de los corredores es:",mediana)
# Out:
# La mediana de los tiempos de los corredores es: 17.2

# %%
#Para usar la moda:
moda=mode(tiempos100mts)
print("La moda de los tiempos es:",moda)
# Out:
# La moda de los tiempos es: 15.1

# %%
#En caso de tener varias modas, osea el numero que más veces se repitió:
multimodas=multimode(tiempos100mts)
print("La moda de los tiempos es:",multimodas)
# Out:
# La moda de los tiempos es: [15.1, 17.2]

# %% [markdown]
# ##Ejemplo 3: Histogramas de dos grupos.
# 1. En este ejemplo generamos 100 numeros aleatorios reales que representa la producción diaria de 100 telares (medidas en metros).
# 2. Generar otra lista con la producción de 100 telares para una segunda fábrica.
# 3. Con estas lista de valores se pretende determinar las medidas de tendencia central, es decir, la media, la moda, la mediana, la desviación estandar.
# 4. Graficar un histograma para cada fábrica.

# %%
#Librería para generar numeros aleatorios.
import random

# %%
fabrica1= []
for i in range(100):
  numaleatorio= round(random.uniform (50,100),2)  #Round me redondeo los numeros a dos decimales, por eso el ,2.
  fabrica1.append(numaleatorio)    #Con el método append, puedes agregar un elemento al final de una lista. Es como colocar un objeto al final de una fila.
print(fabrica1)
# Out:
# [63.92, 83.67, 67.06, 80.53, 58.0, 91.46, 56.28, 93.87, 63.15, 54.28, 51.0, 70.47, 66.55, 63.13, 80.32, 96.13, 68.39, 78.39, 50.13, 54.6, 71.89, 66.48, 56.18, 97.83, 79.25, 77.99, 94.1, 77.21, 69.05, 71.79, 52.95, 62.03, 59.67, 93.94, 82.21, 74.93, 60.44, 78.62, 87.53, 75.25, 93.88, 97.2, 85.84, 76.77, 96.87, 81.11, 81.82, 74.59, 86.01, 53.33, 99.97, 78.5, 58.94, 83.08, 74.61, 60.79, 61.63, 80.86, 83.13, 51.02, 75.45, 83.36, 81.54, 54.59, 80.44, 76.0, 95.66, 66.79, 59.45, 93.76, 62.03, 59.57, 80.51, 51.22, 78.17, 75.5, 59.74, 63.33, 99.48, 78.37, 54.48, 97.76, 93.4, 82.72, 79.61, 89.56, 89.25, 82.28, 59.58, 71.89, 69.85, 77.74, 88.66, 81.93, 88.58, 52.65, 87.99, 51.26, 84.25, 75.28]

# %%
fabrica2= []
for i in range(100):
  numaleatorio2= round(random.uniform (50,100),2)
  fabrica2.append(numaleatorio2)
print(fabrica2)
# Out:
# [54.51, 73.66, 76.02, 87.12, 55.26, 81.41, 56.88, 90.61, 82.47, 90.47, 96.82, 74.17, 55.88, 93.31, 54.91, 84.1, 50.2, 69.54, 61.46, 96.8, 50.4, 73.78, 86.98, 98.37, 84.52, 75.78, 69.15, 75.59, 59.58, 85.98, 93.79, 96.57, 61.33, 98.24, 73.85, 75.17, 50.56, 56.8, 57.33, 81.69, 99.08, 81.29, 89.5, 60.33, 68.45, 62.87, 84.67, 62.2, 96.93, 60.77, 60.04, 75.12, 61.19, 62.17, 56.97, 73.98, 50.4, 92.43, 56.99, 66.52, 66.69, 99.78, 51.94, 80.37, 76.5, 96.77, 71.94, 95.03, 68.46, 80.71, 96.75, 93.64, 51.0, 98.08, 95.03, 84.41, 87.16, 87.88, 82.98, 78.61, 78.5, 53.76, 71.87, 99.61, 76.23, 51.89, 91.33, 57.83, 81.51, 85.01, 59.9, 90.77, 75.53, 90.41, 97.58, 69.59, 56.19, 68.5, 70.52, 63.93]

# %%
#Librería de Python para graficar valores.
import matplotlib.pyplot as plt

#"as plt", es el alias que le dimos debido a que el nombre de la libreria es muy extenso

# %%
plt.hist(fabrica1)  #.hist de histograma, o mejor dicho gráfica.
plt.title("Producción diaria de la Fábrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la Fábrica 1')

# %%
plt.hist(fabrica2)  #.hist de histograma
plt.title("Producción diaria de la Fábrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la Fábrica 2')

# %%
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("Valores de la Fábrica 1")
print("La media es igual a",media)
print("La mediana es igual a",mediana)
print("La moda es igual a",moda)
# Out:
# Valores de la Fábrica 1
# La media es igual a 74.743
# La mediana es igual a 76.99
# La moda es igual a 71.89

# %%
media=mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("Valores de la Fábrica 2")
print("La media es igual a",media)
print("La mediana es igual a",mediana)
print("La moda es igual a",moda)
# Out:
# Valores de la Fábrica 2
# La media es igual a 75.4715
# La mediana es igual a 75.56
# La moda es igual a 50.4

# %%
#Generar dos subplots de 1 renglón por dos columnas para desplegar los dos histogramas, una al lado de la otra.
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2 , figsize=(10,5)) #subplot sirve para poner el area de trazado de nuestros gráficos.
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor mínimo, máximo, rango.
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)

# %%
plt.hist(fabrica1, bins=20, alpha=0.4, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 1")
plt.legend()
plt.show()
#bins son cuantas barritas va a haber.
#legend es el cuadrito de la esquina.

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)


plt.hist(fabrica2, bins=10, alpha=0.4, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##Máximo,Mínimo y Rango

# %%
maximo=max(fabrica1)
minimo=min(fabrica1)
rango= maximo-minimo
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)

print("Estadística Descriptiva de la Fábrica 1 \n", "Media=",media,
      "\n Mediana=",mediana, "\n Moda=",moda, "\n Máximo=",maximo, "\n Mínimo=",minimo, "\n Rango=",rango)
# Out:
# Estadística Descriptiva de la Fábrica 1
#  Media= 74.743
#  Mediana= 76.99
#  Moda= 71.89
#  Máximo= 99.97
#  Mínimo= 50.13
#  Rango= 49.839999999999996

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2= maximo-minimo
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)

print("Estadística Descriptiva de la Fábrica 2 \n", "Media=",media2,
      "\n Mediana=",mediana2, "\n Moda=",moda2, "\n Máximo=",maximo2, "\n Mínimo=",minimo2, "\n Rango=",rango2)
# Out:
# Estadística Descriptiva de la Fábrica 2
#  Media= 75.4715
#  Mediana= 75.56
#  Moda= 50.4
#  Máximo= 99.78
#  Mínimo= 50.2
#  Rango= 49.839999999999996

# %% [markdown]
# ##Dispersión de los datos

# %%
desviacionestandar_fabrica1= stdev(fabrica1)
print("La Desviación Estandar de la Fábrica1 es=",desviacionestandar_fabrica1)
# Out:
# La Desviación Estandar de la Fábrica1 es= 13.926212802851428

# %%
desviacionestandar_fabrica2= stdev(fabrica2)
print("La Desviación Estandar de la Fábrica2 es=",desviacionestandar_fabrica2)
# Out:
# La Desviación Estandar de la Fábrica2 es= 15.221433743311444

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media1 - desviacionestandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv Estandar={desviacionestandar_fabrica1:.2f}')
plt.axvline(media1 + desviacionestandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.hist(fabrica2, bins=10, alpha=0.4, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')

plt.axvline(media2 - desviacionestandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv Estandar={desviacionestandar_fabrica2:.2f}')
plt.axvline(media2 + desviacionestandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la Fábrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de Frecuencia

# %%
#Generamos una lista vacía que representa la edad de un grupo de personas.
edades=[]
for i in range(100):
  numero_aleatorio=random.randint (18,70)
  edades.append(numero_aleatorio)
print (edades)
# Out:
# [62, 21, 49, 51, 65, 40, 31, 65, 48, 51, 70, 42, 49, 53, 60, 48, 68, 40, 50, 23, 65, 47, 67, 61, 60, 28, 38, 44, 48, 36, 60, 18, 33, 22, 58, 45, 60, 63, 35, 56, 36, 30, 61, 65, 46, 23, 29, 49, 50, 57, 38, 66, 70, 38, 49, 56, 48, 20, 39, 23, 53, 46, 63, 61, 22, 45, 32, 19, 21, 60, 65, 67, 21, 47, 56, 44, 36, 33, 66, 42, 37, 70, 31, 68, 22, 57, 40, 39, 33, 37, 21, 18, 57, 46, 63, 68, 62, 33, 65, 33]

# %%
import pandas as pd
#Pandas es una biblioteca de Python que se utiliza principalmente para análisis de datos y manipulación de datos estructurados.

# %%
df_edades = pd.DataFrame(edades,columns=["Edad"])
df_edades #Imprimo el dataframe.
# Out:
#     Edad
# 0     62
# 1     21
# 2     49
# 3     51
# 4     65
# ..   ...
# 95    68
# 96    62
# 97    33
# 98    65
# 99    33
#
# [100 rows x 1 columns]

# %%
#Calcular la tabla de distribución de frecuencias.
tabla_frecuencias=df_edades["Edad"].value_counts().reset_index() #Para ordenarlo por edades.
tabla_frecuencias.columns = ["Edad","Frecuencia"] #Agrego columna de Frecuencia.
tabla_frecuencias = tabla_frecuencias.sort_values(by="Edad") #Ordena los valores por Edad.
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 23    18           2
# 39    19           1
# 36    20           1
# 4     21           4
# 8     22           3
# 11    23           3
# 34    28           1
# 35    29           1
# 33    30           1
# 26    31           2
# 38    32           1
# 2     33           5
# 32    35           1
# 12    36           3
# 31    37           2
# 7     38           3
# 20    39           2
# 17    40           3
# 27    42           2
# 22    44           2
# 18    45           2
# 14    46           3
# 29    47           2
# 5     48           4
# 3     49           4
# 24    50           2
# 25    51           2
# 28    53           2
# 6     56           3
# 15    57           3
# 37    58           1
# 1     60           5
# 9     61           3
# 21    62           2
# 10    63           3
# 0     65           6
# 19    66           2
# 30    67           2
# 13    68           3
# 16    70           3

# %%
tabla_frecuencias["Frec. Relativa"] = tabla_frecuencias["Frecuencia"] / 100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 23    18           2            0.02
# 39    19           1            0.01
# 36    20           1            0.01
# 4     21           4            0.04
# 8     22           3            0.03
# 11    23           3            0.03
# 34    28           1            0.01
# 35    29           1            0.01
# 33    30           1            0.01
# 26    31           2            0.02
# 38    32           1            0.01
# 2     33           5            0.05
# 32    35           1            0.01
# 12    36           3            0.03
# 31    37           2            0.02
# 7     38           3            0.03
# 20    39           2            0.02
# 17    40           3            0.03
# 27    42           2            0.02
# 22    44           2            0.02
# 18    45           2            0.02
# 14    46           3            0.03
# 29    47           2            0.02
# 5     48           4            0.04
# ...

# %%
#Calcular la Frecuencia Porcentual:
tabla_frecuencias["Frec. Porcentual"] = tabla_frecuencias["Frecuencia"]/ 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual
# 23    18           2            0.02               2.0
# 39    19           1            0.01               1.0
# 36    20           1            0.01               1.0
# 4     21           4            0.04               4.0
# 8     22           3            0.03               3.0
# 11    23           3            0.03               3.0
# 34    28           1            0.01               1.0
# 35    29           1            0.01               1.0
# 33    30           1            0.01               1.0
# 26    31           2            0.02               2.0
# 38    32           1            0.01               1.0
# 2     33           5            0.05               5.0
# 32    35           1            0.01               1.0
# 12    36           3            0.03               3.0
# 31    37           2            0.02               2.0
# 7     38           3            0.03               3.0
# ...

# %%
#Calcular la frecuencia acumulada:
#Agregamos una nueva columna con el cálculo
tabla_frecuencias["Frec. Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Acumulada
# 23    18           2            0.02               2.0                2
# 39    19           1            0.01               1.0                3
# 36    20           1            0.01               1.0                4
# 4     21           4            0.04               4.0                8
# 8     22           3            0.03               3.0               11
# 11    23           3            0.03               3.0               14
# 34    28           1            0.01               1.0               15
# 35    29           1            0.01               1.0               16
# 33    30           1            0.01               1.0               17
# 26    31           2            0.02               2.0               19
# 38    32           1            0.01               1.0               20
# 2     33           5            0.05               5.0               25
# ...

# %% [markdown]
# ##Regla de Sturges
# 1.- Es una regla que sirve para calcular el número de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos.
#
# $
# c = 1+Log_2(N)
# $

# %%
#Librería de funciones matemáticas:
import math

# %%
print(edades)
# Out:
# [62, 21, 49, 51, 65, 40, 31, 65, 48, 51, 70, 42, 49, 53, 60, 48, 68, 40, 50, 23, 65, 47, 67, 61, 60, 28, 38, 44, 48, 36, 60, 18, 33, 22, 58, 45, 60, 63, 35, 56, 36, 30, 61, 65, 46, 23, 29, 49, 50, 57, 38, 66, 70, 38, 49, 56, 48, 20, 39, 23, 53, 46, 63, 61, 22, 45, 32, 19, 21, 60, 65, 67, 21, 47, 56, 44, 36, 33, 66, 42, 37, 70, 31, 68, 22, 57, 40, 39, 33, 37, 21, 18, 57, 46, 63, 68, 62, 33, 65, 33]

# %%
plt.hist(edades,alpha=0.5,rwidth=0.90)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df_edades_sturges = pd.DataFrame({"Edad":edades})
df_edades_sturges
# Out:
#     Edad
# 0     62
# 1     21
# 2     49
# 3     51
# 4     65
# ..   ...
# 95    68
# 96    62
# 97    33
# 98    65
# 99    33
#
# [100 rows x 1 columns]

# %%
#Calcular el número de intervalos o clases utilizando la regla de Sturges:
n = len(edades)
k = int(1+math.log2(n))
print("Valor de n=",n,"\n K o número de intervalos o clases=",k)
# Out:
# Valor de n= 100
#  K o número de intervalos o clases= 7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (32.857, 40.286]    19
# 1    (62.571, 70.0]    19
# 2  (55.143, 62.571]    17
# 3  (17.948, 25.429]    14
# 4  (47.714, 55.143]    14
# 5  (40.286, 47.714]    11
# 6  (25.429, 32.857]     6

# %%
tabla_frec_sturges.columns=["Clase","Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (32.857, 40.286]          19
# 1    (62.571, 70.0]          19
# 2  (55.143, 62.571]          17
# 3  (17.948, 25.429]          14
# 4  (47.714, 55.143]          14
# 5  (40.286, 47.714]          11
# 6  (25.429, 32.857]           6

# %%
#Ordenar la tabla de frecuencias por la clase o el intervalo:
tabla_frec_sturges = tabla_frec_sturges.sort_values(by="Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 3  (17.948, 25.429]          14
# 6  (25.429, 32.857]           6
# 0  (32.857, 40.286]          19
# 5  (40.286, 47.714]          11
# 4  (47.714, 55.143]          14
# 2  (55.143, 62.571]          17
# 1    (62.571, 70.0]          19

# %%
tabla_frec_sturges["Frec.Relativa"] = tabla_frec_sturges["Frecuencia"]/n
tabla_frec_sturges["Frec.Porcentual"] = tabla_frec_sturges["Frecuencia"]/n*100
tabla_frec_sturges["Frec.Acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec.Relativa  Frec.Porcentual  \
# 3  (17.948, 25.429]          14           0.14             14.0
# 6  (25.429, 32.857]           6           0.06              6.0
# 0  (32.857, 40.286]          19           0.19             19.0
# 5  (40.286, 47.714]          11           0.11             11.0
# 4  (47.714, 55.143]          14           0.14             14.0
# 2  (55.143, 62.571]          17           0.17             17.0
# 1    (62.571, 70.0]          19           0.19             19.0
#
#    Frec.Acumulada
# 3              14
# 6              20
# 0              39
# 5              50
# 4              64
# 2              81
# 1             100

# %%
plt.hist(df_edades_sturges["Edad"], bins=k, alpha=0.5, rwidth=.95)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ##Practica 5 - Diagramas de Cajas y Bigotes.

# %%
print(fabrica1)
# Out:
# [63.92, 83.67, 67.06, 80.53, 58.0, 91.46, 56.28, 93.87, 63.15, 54.28, 51.0, 70.47, 66.55, 63.13, 80.32, 96.13, 68.39, 78.39, 50.13, 54.6, 71.89, 66.48, 56.18, 97.83, 79.25, 77.99, 94.1, 77.21, 69.05, 71.79, 52.95, 62.03, 59.67, 93.94, 82.21, 74.93, 60.44, 78.62, 87.53, 75.25, 93.88, 97.2, 85.84, 76.77, 96.87, 81.11, 81.82, 74.59, 86.01, 53.33, 99.97, 78.5, 58.94, 83.08, 74.61, 60.79, 61.63, 80.86, 83.13, 51.02, 75.45, 83.36, 81.54, 54.59, 80.44, 76.0, 95.66, 66.79, 59.45, 93.76, 62.03, 59.57, 80.51, 51.22, 78.17, 75.5, 59.74, 63.33, 99.48, 78.37, 54.48, 97.76, 93.4, 82.72, 79.61, 89.56, 89.25, 82.28, 59.58, 71.89, 69.85, 77.74, 88.66, 81.93, 88.58, 52.65, 87.99, 51.26, 84.25, 75.28]

# %%
plt.boxplot(fabrica1)
plt.title("Producción de la Fábrica 1")
plt.ylabel("Producción en metros")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(fabrica2)
plt.title("Producción de la Fábrica 2")
plt.ylabel("Producción en metros")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###Comparamos la producción de la fábrica 1 y la fábrica 2 con un diagrama de cajas y bigotes.

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
ax1.boxplot(fabrica1, vert=True, patch_artist= True) #El parametro "patch_artist" me sirve para que tenga un color de relleno.
ax1.set_title("Producción de la Fábrica 1")

ax2.boxplot(fabrica2, vert=True, patch_artist= True)
ax2.set_title("Producción de la Fábrica 2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(fabrica2)
# Out:
# [54.51, 73.66, 76.02, 87.12, 55.26, 81.41, 56.88, 90.61, 82.47, 90.47, 96.82, 74.17, 55.88, 93.31, 54.91, 84.1, 50.2, 69.54, 61.46, 96.8, 50.4, 73.78, 86.98, 98.37, 84.52, 75.78, 69.15, 75.59, 59.58, 85.98, 93.79, 96.57, 61.33, 98.24, 73.85, 75.17, 50.56, 56.8, 57.33, 81.69, 99.08, 81.29, 89.5, 60.33, 68.45, 62.87, 84.67, 62.2, 96.93, 60.77, 60.04, 75.12, 61.19, 62.17, 56.97, 73.98, 50.4, 92.43, 56.99, 66.52, 66.69, 99.78, 51.94, 80.37, 76.5, 96.77, 71.94, 95.03, 68.46, 80.71, 96.75, 93.64, 51.0, 98.08, 95.03, 84.41, 87.16, 87.88, 82.98, 78.61, 78.5, 53.76, 71.87, 99.61, 76.23, 51.89, 91.33, 57.83, 81.51, 85.01, 59.9, 90.77, 75.53, 90.41, 97.58, 69.59, 56.19, 68.5, 70.52, 63.93]

# %%
fabrica2.append(150) #Aquí le agregamos un valor atípico, y recuerda que el metodo append te agrega a la lista de valores ese dato.
print(fabrica2)
# Out:
# [54.51, 73.66, 76.02, 87.12, 55.26, 81.41, 56.88, 90.61, 82.47, 90.47, 96.82, 74.17, 55.88, 93.31, 54.91, 84.1, 50.2, 69.54, 61.46, 96.8, 50.4, 73.78, 86.98, 98.37, 84.52, 75.78, 69.15, 75.59, 59.58, 85.98, 93.79, 96.57, 61.33, 98.24, 73.85, 75.17, 50.56, 56.8, 57.33, 81.69, 99.08, 81.29, 89.5, 60.33, 68.45, 62.87, 84.67, 62.2, 96.93, 60.77, 60.04, 75.12, 61.19, 62.17, 56.97, 73.98, 50.4, 92.43, 56.99, 66.52, 66.69, 99.78, 51.94, 80.37, 76.5, 96.77, 71.94, 95.03, 68.46, 80.71, 96.75, 93.64, 51.0, 98.08, 95.03, 84.41, 87.16, 87.88, 82.98, 78.61, 78.5, 53.76, 71.87, 99.61, 76.23, 51.89, 91.33, 57.83, 81.51, 85.01, 59.9, 90.77, 75.53, 90.41, 97.58, 69.59, 56.19, 68.5, 70.52, 63.93, 150]

# %%
#Representación del valor atípico:
plt.boxplot(fabrica2)
plt.title("Producción de la Fábrica 2")
plt.ylabel("Producción en metros")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
